# %% [markdown]
# <a href="https://colab.research.google.com/github/balamurugan-palaniappan-CEP/AIML_CEP_2021/blob/main/Bandits/MultiArmedBandit_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Explore then Exploit strategy

# %% [markdown]
# # Single Episode

# %%
#import the required libraries 
import numpy as np
import matplotlib.pyplot as plt 

n = 10 #number of arms 
expected_payouts = np.asarray([10.,40.,50.,76.,90.,79.,0.,29.,85.,65.]) #actual mean payouts of arms, unknown to the users


k = 1000 #total rounds 

m = 50 #number of initial rounds to explore each arm 

avg_rewards_over_rounds = np.zeros(k)

np.random.seed(10000) #for reproducibility 

def get_reward(arm): #returns an approximately normally distributed reward thresholded between [0,100]
    reward = np.random.normal(loc=expected_payouts[arm], scale=60)
    if reward<0:
        reward = 0.0
    elif reward > 100.0:
        reward = 100.0
    return reward 

def find_best_arm_single_episode():
    rewards_arms = np.zeros(n)
    round_idx = 0
    for arm in range(n):
        for idx in range(m):
            rewards_arms[arm] += get_reward(arm)
            avg_rewards_over_rounds[round_idx] = np.sum(rewards_arms)/(round_idx+1)
            round_idx += 1
    avg_rewards_arms = rewards_arms/(m) #compute average reward
    plt.bar(np.arange(0,n),avg_rewards_arms)    
    plt.xlabel("Arm")
    plt.ylabel("Average reward after m=%d rounds"%(m))
    plt.title("Average reward distribution of all arms after nm=%d rounds"%(n*m))
    plt.show()
    
    best_arm = np.argmax(avg_rewards_arms)
    
    print('best arm:',(best_arm))
    return best_arm, rewards_arms, avg_rewards_arms, avg_rewards_over_rounds

    
def play_multi_armed_bandit_single_episode():
    #explore phase 
    best_arm, rewards_arms, avg_rewards_arms, avg_rewards_over_rounds = find_best_arm_single_episode()
                                     
    #exploit phase 
    for round_idx in np.arange(n*m,k):
        rewards_arms[best_arm] += get_reward(best_arm)
        avg_rewards_over_rounds[round_idx] = np.sum(rewards_arms)/(round_idx+1)
    avg_rewards_arms[best_arm] = rewards_arms[best_arm]/(k-n*m)

    print('Rounds:',k,' Overall avg reward:',avg_rewards_over_rounds[-1])

    plt.plot(avg_rewards_over_rounds)    
    plt.xlabel("Round")
    plt.ylabel("Average reward over rounds")
    plt.title("Average reward behavior over rounds")
    plt.show()
    
    
    
if __name__ == '__main__':
  play_multi_armed_bandit_single_episode()
# Out:
# best arm: 4
# Rounds: 1000  Overall avg reward: 60.324842621637025

# %% [markdown]
# $\large{\textbf{Exercise 1}}$: Try $m \in \{1,2,4,8,16,32\}$ and scale$\in\{10,20,30,40,50,60,70,80,90\}$ and run the code and tabulate the best arm and average reward obtained at the end of 1000 rounds.
#
# $\large{\textbf{Exercise 2}}$: Try the following expected payouts for the 10 arms and repeat the experiments in Exercise 1.
#
# i) [82.,84.,86.,88.,90.,92.,94.,96.,98.,100.]
# ii) [86., 30., 0., 2., 79., 50., 90., 12., 95., 8.]

# %% [markdown]
# # Multiple episodes

# %%
#import the required libraries 
import numpy as np
import matplotlib.pyplot as plt 
from timeit import default_timer as timer

n = 10 #number of arms 
expected_payouts = np.asarray([10.,40.,50.,76.,90.,79.,0.,29.,85.,65.])



np.random.seed(200) #for reproducibility 

def get_reward(arm):
    reward = np.random.normal(loc=expected_payouts[arm], scale=60)
    if reward<0:
        reward = 0.0
    elif reward > 100.0:
        reward = 100.0
    return reward 

def find_best_arm_explore_then_exploit(avg_rewards_over_rounds, m):
    rewards_arms = np.zeros(n)
    round_idx = 0
    for arm in range(n):
        for idx in range(m):
            rewards_arms[arm] += get_reward(arm)
            avg_rewards_over_rounds[round_idx] = np.sum(rewards_arms)/(round_idx+1)
            round_idx += 1
    avg_rewards_arms = rewards_arms/(m) #compute average reward
#     plt.bar(np.arange(1,n+1),avg_rewards_arms)    
#     plt.xlabel("Arm")
#     plt.ylabel("Average reward after m=%d rounds"%(m))
#     plt.title("Average reward distribution of all arms after nm=%d rounds"%(n*m))
#     plt.show()
    
    best_arm = np.argmax(avg_rewards_arms)
    
    #print('best arm:',(best_arm+1))
    return best_arm, rewards_arms, avg_rewards_arms, avg_rewards_over_rounds

    
def play_multi_armed_bandit_explore_then_exploit(num_rounds):
    k = num_rounds #total rounds 

    m = 50 #number of initial rounds to explore each arm 

    avg_rewards_over_rounds = np.zeros(k)

    #explore phase 
    best_arm, rewards_arms, avg_rewards_arms, avg_rewards_over_rounds = find_best_arm_explore_then_exploit(avg_rewards_over_rounds,m)
                                     
    #exploit phase 
    for round_idx in np.arange(n*m,k):
        rewards_arms[best_arm] += get_reward(best_arm)
        avg_rewards_over_rounds[round_idx] = np.sum(rewards_arms)/(round_idx+1)
    avg_rewards_arms[best_arm] = rewards_arms[best_arm]/(k-n*m)


    #print('Rounds:',k,' Overall avg reward:',avg_rewards_over_rounds[-1])
    return avg_rewards_over_rounds
    
    
    
def run_multi_armed_bandit_epsiodes_explore_then_exploit(num_episodes):
    assert num_episodes>0
    long_term_avg_reward = np.zeros(num_episodes)
    num_rounds_in_single_episode = 1000
    for episode in range(num_episodes):
        #print('################### episode: %d #################' %episode)
        avg_rewards_all_rounds_single_episode = play_multi_armed_bandit_explore_then_exploit(num_rounds_in_single_episode)   
        long_term_avg_reward = (episode*long_term_avg_reward + avg_rewards_all_rounds_single_episode)/(episode+1)
        #print('################### end of episode: %d #################' %episode)
    return long_term_avg_reward
    

if __name__ == '__main__':
    episodes = 1000

    start_time = timer()
    long_term_avg_reward_explore_then_exploit = run_multi_armed_bandit_epsiodes_explore_then_exploit(episodes)
    end_time = timer() 

    print('Explore them Exploit: Total time taken:',end_time-start_time, 'seconds!')
    plt.plot(long_term_avg_reward_explore_then_exploit)    
    plt.xlabel("Round")
    plt.ylabel("Average reward across %d episodes"%episodes)
    plt.title("Average reward behavior over episodes")
    plt.show()
# Out:
# Explore them Exploit: Total time taken: 12.039939021999999 seconds!

# %% [markdown]
# $\large{\textbf{Exercise 3}}$: Try $m \in \{1,2,4,8,16,32\}$ and scale$\in\{10,20,30,40,50,60,70,80,90\}$ and run the code for multiple episodes of Explore-then-Exploit strategy and tabulate the average reward obtained at the end of 1000 episodes.

# %% [markdown]
# # Combined Explore-Exploit strategy

# %% [markdown]
# # Single episode

# %%
#import the required libraries 
import numpy as np
import matplotlib.pyplot as plt 

n = 10 #number of arms 
expected_payouts = np.asarray([10.,40.,50.,76.,90.,79.,0.,29.,85.,65.])


k = 1000 #total rounds 

#m = 50 #number of initial rounds to explore each arm 

avg_rewards_over_rounds = np.zeros(k)

np.random.seed(100) #for reproducibility

def get_reward(arm):
    reward = np.random.normal(loc=expected_payouts[arm], scale=60)
    if reward<0:
        reward = 0.0
    elif reward > 100.0:
        reward = 100.0
    return reward 

def find_best_arm_combined_explore_exploit_single_episode(avg_rewards_arms):
    best_arm = np.argmax(avg_rewards_arms)
    
    #print('best arm:',(best_arm+1))
    return best_arm

    
def play_multi_armed_bandit_combined_explore_exploit_single_episode():
    epsilon = 0.2
    avg_rewards_arms = np.zeros(n)
    freq_arms = np.zeros(n)
    for round_idx in range(k):
        if round_idx == 0: #first round 
            arm = np.random.randint(0, n)
            print('round:',round_idx,'arm:',arm)
            reward = get_reward(arm)
            avg_rewards_over_rounds[round_idx] = reward
            # we maintain a running average of rewards of each arm            
            avg_rewards_arms[arm] = (avg_rewards_arms[arm]*freq_arms[arm] + reward)/(freq_arms[arm]+1) 
            freq_arms[arm] += 1.
        else: #for other rounds 
            r = np.random.rand()
            best_arm = find_best_arm_combined_explore_exploit_single_episode(avg_rewards_arms)
            if r>epsilon: #use the best arm in the previous history
                #play the best arm so far 
                print('round:',round_idx,'best arm:',best_arm)
                reward = get_reward(best_arm)
                avg_rewards_over_rounds[round_idx] = (((round_idx)*avg_rewards_over_rounds[round_idx-1])+reward)/(round_idx+1)
                # we maintain a running average of rewards of each arm            
                avg_rewards_arms[best_arm] = (avg_rewards_arms[best_arm]*freq_arms[best_arm] + reward)/(freq_arms[best_arm]+1) 
                freq_arms[best_arm] += 1.
            else: #explore another arm other than the best arm so far
                arm = np.random.randint(0, n)
                print('round:',round_idx,'arm:',arm)
                while arm==best_arm:
                    arm = np.random.randint(0, n)
                reward = get_reward(arm)
                avg_rewards_over_rounds[round_idx] = (((round_idx)*avg_rewards_over_rounds[round_idx-1])+reward)/(round_idx+1)
                # we maintain a running average of rewards of each arm            
                avg_rewards_arms[arm] = (avg_rewards_arms[arm]*freq_arms[arm] + reward)/(freq_arms[arm]+1) 
                freq_arms[arm] += 1.
            #print(avg_rewards_arms)
                
    

    print('Rounds:',k,' Overall avg reward:',avg_rewards_over_rounds[-1])

    plt.plot(avg_rewards_over_rounds)    
    plt.xlabel("Round")
    plt.ylabel("Average reward over rounds")
    plt.title("Average reward behavior over rounds")
    plt.show()
    
    plt.bar(np.arange(0,n),avg_rewards_arms)    
    plt.xlabel("Arm")
    plt.ylabel("Average reward after k=%d rounds"%(k))
    plt.title("Average reward distribution of all arms after k=%d rounds"%(k))
    plt.show()

    
play_multi_armed_bandit_combined_explore_exploit_single_episode()
# Out:
# round: 0 arm: 8
# round: 1 best arm: 8
# round: 2 arm: 4
# round: 3 best arm: 4
# round: 4 arm: 8
# round: 5 best arm: 8
# round: 6 best arm: 4
# round: 7 best arm: 4
# round: 8 best arm: 4
# round: 9 best arm: 4
# round: 10 best arm: 4
# round: 11 best arm: 4
# round: 12 arm: 5
# round: 13 best arm: 4
# round: 14 best arm: 4
# round: 15 best arm: 4
# round: 16 best arm: 4
# round: 17 best arm: 4
# round: 18 arm: 4
# round: 19 arm: 3
# round: 20 arm: 4
# round: 21 best arm: 3
# round: 22 best arm: 3
# round: 23 best arm: 2
# round: 24 arm: 2
# round: 25 best arm: 3
# round: 26 arm: 6
# round: 27 best arm: 4
# round: 28 best arm: 4
# round: 29 best arm: 4
# round: 30 arm: 0
# round: 31 best arm: 8
# round: 32 best arm: 4
# round: 33 best arm: 4
# round: 34 best arm: 4
# round: 35 arm: 4
# round: 36 best arm: 4
# round: 37 best arm: 4
# round: 38 best arm: 4
# round: 39 best arm: 4
# round: 40 best arm: 4
# round: 41 best arm: 4
# round: 42 best arm: 4
# round: 43 best arm: 4
# round: 44 arm: 4
# round: 45 best arm: 4
# round: 46 best arm: 4
# round: 47 best arm: 4
# round: 48 best arm: 4
# round: 49 best arm: 4
# round: 50 best arm: 4
# round: 51 best arm: 4
# round: 52 best arm: 4
# round: 53 best arm: 4
# round: 54 best arm: 4
# round: 55 arm: 8
# round: 56 best arm: 4
# round: 57 arm: 6
# round: 58 best arm: 4
# round: 59 best arm: 4
# round: 60 best arm: 4
# round: 61 best arm: 4
# round: 62 best arm: 4
# round: 63 arm: 4
# round: 64 best arm: 4
# round: 65 best arm: 4
# round: 66 arm: 8
# round: 67 best arm: 4
# round: 68 best arm: 4
# round: 69 best arm: 4
# round: 70 best arm: 4
# round: 71 arm: 6
# round: 72 best arm: 4
# round: 73 best arm: 4
# round: 74 best arm: 4
# round: 75 best arm: 4
# round: 76 best arm: 4
# round: 77 arm: 7
# round: 78 arm: 0
# round: 79 best arm: 7
# round: 80 best arm: 0
# round: 81 arm: 3
# round: 82 best arm: 4
# round: 83 best arm: 4
# round: 84 best arm: 4
# round: 85 best arm: 4
# round: 86 arm: 2
# round: 87 best arm: 4
# round: 88 best arm: 4
# round: 89 arm: 9
# round: 90 best arm: 4
# round: 91 arm: 3
# round: 92 arm: 5
# round: 93 arm: 3
# round: 94 best arm: 4
# round: 95 best arm: 4
# round: 96 best arm: 4
# round: 97 best arm: 4
# round: 98 best arm: 4
# round: 99 best arm: 4
# round: 100 arm: 3
# round: 101 arm: 6
# round: 102 best arm: 4
# round: 103 best arm: 4
# round: 104 best arm: 4
# round: 105 best arm: 4
# round: 106 best arm: 4
# round: 107 best arm: 4
# round: 108 best arm: 4
# round: 109 best arm: 4
# round: 110 best arm: 4
# round: 111 arm: 1
# round: 112 best arm: 4
# round: 113 best arm: 4
# round: 114 arm: 1
# round: 115 arm: 5
# round: 116 best arm: 4
# round: 117 arm: 6
# round: 118 best arm: 4
# round: 119 best arm: 4
# round: 120 arm: 5
# round: 121 best arm: 4
# round: 122 best arm: 4
# round: 123 best arm: 4
# round: 124 best arm: 4
# round: 125 best arm: 4
# round: 126 arm: 7
# round: 127 best arm: 4
# round: 128 best arm: 4
# round: 129 best arm: 4
# round: 130 arm: 1
# round: 131 best arm: 4
# round: 132 best arm: 4
# round: 133 best arm: 4
# round: 134 best arm: 4
# round: 135 best arm: 4
# round: 136 best arm: 4
# round: 137 best arm: 4
# round: 138 arm: 8
# round: 139 best arm: 4
# round: 140 best arm: 4
# round: 141 best arm: 4
# round: 142 best arm: 4
# round: 143 arm: 3
# round: 144 best arm: 4
# round: 145 best arm: 4
# round: 146 best arm: 4
# round: 147 best arm: 4
# round: 148 best arm: 4
# round: 149 best arm: 4
# round: 150 best arm: 4
# round: 151 best arm: 4
# round: 152 best arm: 4
# round: 153 best arm: 4
# round: 154 best arm: 4
# round: 155 arm: 6
# round: 156 arm: 8
# round: 157 best arm: 4
# round: 158 best arm: 4
# round: 159 arm: 2
# round: 160 best arm: 4
# round: 161 best arm: 4
# round: 162 best arm: 4
# round: 163 best arm: 4
# round: 164 best arm: 4
# round: 165 best arm: 4
# round: 166 best arm: 4
# round: 167 best arm: 4
# round: 168 best arm: 4
# round: 169 best arm: 4
# round: 170 arm: 0
# round: 171 best arm: 4
# round: 172 best arm: 4
# round: 173 best arm: 4
# round: 174 best arm: 4
# round: 175 best arm: 4
# round: 176 best arm: 4
# round: 177 best arm: 4
# round: 178 arm: 0
# round: 179 best arm: 4
# round: 180 best arm: 4
# round: 181 arm: 7
# round: 182 best arm: 4
# round: 183 best arm: 4
# round: 184 best arm: 4
# round: 185 best arm: 4
# round: 186 best arm: 4
# round: 187 best arm: 4
# round: 188 best arm: 4
# round: 189 best arm: 4
# round: 190 best arm: 4
# round: 191 best arm: 4
# round: 192 best arm: 4
# round: 193 best arm: 4
# round: 194 arm: 7
# round: 195 best arm: 4
# round: 196 best arm: 4
# round: 197 best arm: 4
# round: 198 best arm: 4
# round: 199 best arm: 4
# round: 200 arm: 1
# round: 201 best arm: 4
# round: 202 best arm: 4
# round: 203 best arm: 4
# round: 204 best arm: 4
# round: 205 best arm: 4
# round: 206 arm: 5
# round: 207 best arm: 4
# round: 208 best arm: 4
# round: 209 best arm: 4
# round: 210 best arm: 4
# round: 211 arm: 7
# round: 212 best arm: 4
# round: 213 best arm: 4
# round: 214 best arm: 4
# round: 215 best arm: 4
# round: 216 best arm: 4
# round: 217 best arm: 4
# round: 218 best arm: 4
# round: 219 arm: 6
# round: 220 best arm: 4
# round: 221 best arm: 4
# round: 222 arm: 8
# round: 223 best arm: 8
# round: 224 arm: 2
# round: 225 best arm: 4
# round: 226 best arm: 4
# round: 227 best arm: 4
# round: 228 best arm: 4
# round: 229 best arm: 4
# round: 230 best arm: 4
# round: 231 best arm: 4
# round: 232 best arm: 4
# round: 233 best arm: 4
# round: 234 best arm: 4
# round: 235 best arm: 4
# round: 236 arm: 9
# round: 237 best arm: 4
# round: 238 best arm: 4
# round: 239 best arm: 4
# round: 240 arm: 9
# round: 241 best arm: 4
# round: 242 best arm: 4
# round: 243 arm: 7
# round: 244 best arm: 4
# round: 245 best arm: 4
# round: 246 best arm: 4
# round: 247 best arm: 4
# round: 248 best arm: 4
# round: 249 best arm: 4
# round: 250 arm: 7
# round: 251 best arm: 4
# round: 252 arm: 2
# round: 253 best arm: 4
# round: 254 best arm: 4
# round: 255 best arm: 4
# round: 256 best arm: 4
# round: 257 best arm: 4
# round: 258 best arm: 4
# round: 259 best arm: 4
# round: 260 best arm: 4
# round: 261 arm: 0
# round: 262 best arm: 4
# round: 263 best arm: 4
# round: 264 best arm: 4
# round: 265 best arm: 4
# round: 266 best arm: 4
# round: 267 arm: 1
# round: 268 best arm: 4
# round: 269 arm: 2
# round: 270 best arm: 4
# round: 271 best arm: 4
# round: 272 best arm: 4
# round: 273 best arm: 4
# round: 274 best arm: 4
# round: 275 best arm: 4
# round: 276 best arm: 4
# round: 277 arm: 0
# round: 278 best arm: 4
# round: 279 arm: 4
# round: 280 best arm: 4
# round: 281 best arm: 4
# round: 282 arm: 4
# round: 283 arm: 6
# round: 284 best arm: 4
# round: 285 arm: 2
# round: 286 best arm: 4
# round: 287 best arm: 4
# round: 288 arm: 4
# round: 289 arm: 6
# round: 290 best arm: 4
# round: 291 best arm: 4
# round: 292 best arm: 4
# round: 293 best arm: 4
# round: 294 best arm: 4
# round: 295 arm: 8
# round: 296 best arm: 4
# round: 297 best arm: 4
# round: 298 best arm: 4
# round: 299 best arm: 4
# round: 300 best arm: 4
# round: 301 best arm: 4
# round: 302 best arm: 4
# round: 303 best arm: 4
# round: 304 best arm: 4
# round: 305 arm: 3
# round: 306 best arm: 4
# round: 307 best arm: 4
# round: 308 best arm: 4
# round: 309 best arm: 4
# round: 310 best arm: 4
# round: 311 best arm: 4
# round: 312 best arm: 4
# round: 313 best arm: 4
# round: 314 best arm: 4
# round: 315 best arm: 4
# round: 316 best arm: 4
# round: 317 best arm: 4
# round: 318 arm: 4
# round: 319 best arm: 4
# round: 320 best arm: 4
# round: 321 arm: 6
# round: 322 best arm: 4
# round: 323 best arm: 4
# round: 324 best arm: 4
# round: 325 arm: 7
# round: 326 best arm: 4
# round: 327 best arm: 4
# round: 328 best arm: 4
# round: 329 arm: 0
# round: 330 best arm: 4
# round: 331 best arm: 4
# round: 332 best arm: 4
# round: 333 best arm: 4
# round: 334 best arm: 4
# round: 335 best arm: 4
# round: 336 arm: 4
# round: 337 arm: 6
# round: 338 best arm: 4
# round: 339 arm: 5
# round: 340 best arm: 4
# round: 341 best arm: 4
# round: 342 arm: 2
# round: 343 best arm: 4
# round: 344 best arm: 4
# round: 345 best arm: 4
# round: 346 best arm: 4
# round: 347 best arm: 4
# round: 348 best arm: 4
# round: 349 best arm: 4
# round: 350 arm: 0
# round: 351 best arm: 4
# round: 352 best arm: 4
# round: 353 best arm: 4
# round: 354 best arm: 4
# round: 355 best arm: 4
# round: 356 best arm: 4
# round: 357 arm: 5
# round: 358 best arm: 4
# round: 359 best arm: 4
# round: 360 best arm: 4
# round: 361 best arm: 4
# round: 362 arm: 8
# round: 363 best arm: 4
# round: 364 best arm: 4
# round: 365 best arm: 4
# round: 366 best arm: 4
# round: 367 best arm: 4
# round: 368 best arm: 4
# round: 369 best arm: 4
# round: 370 arm: 5
# round: 371 best arm: 4
# round: 372 best arm: 4
# round: 373 best arm: 4
# round: 374 best arm: 4
# round: 375 best arm: 4
# round: 376 arm: 6
# round: 377 best arm: 4
# round: 378 best arm: 4
# round: 379 best arm: 4
# round: 380 best arm: 4
# round: 381 best arm: 4
# round: 382 best arm: 4
# round: 383 best arm: 4
# round: 384 best arm: 4
# round: 385 best arm: 4
# round: 386 best arm: 4
# round: 387 best arm: 4
# round: 388 arm: 8
# round: 389 best arm: 4
# round: 390 best arm: 4
# round: 391 best arm: 4
# round: 392 best arm: 4
# round: 393 best arm: 4
# round: 394 best arm: 4
# round: 395 best arm: 4
# round: 396 arm: 8
# round: 397 best arm: 4
# round: 398 best arm: 4
# round: 399 best arm: 4
# round: 400 best arm: 4
# round: 401 best arm: 4
# round: 402 best arm: 4
# round: 403 best arm: 4
# round: 404 best arm: 4
# round: 405 arm: 0
# round: 406 arm: 3
# round: 407 arm: 6
# round: 408 best arm: 8
# round: 409 arm: 2
# round: 410 best arm: 4
# round: 411 arm: 6
# round: 412 arm: 9
# round: 413 best arm: 4
# round: 414 best arm: 4
# round: 415 best arm: 4
# round: 416 best arm: 4
# round: 417 best arm: 4
# round: 418 arm: 9
# round: 419 best arm: 4
# round: 420 best arm: 4
# round: 421 best arm: 4
# round: 422 best arm: 4
# round: 423 best arm: 4
# round: 424 best arm: 4
# round: 425 arm: 2
# round: 426 best arm: 4
# round: 427 best arm: 4
# round: 428 arm: 7
# round: 429 best arm: 4
# round: 430 best arm: 4
# round: 431 best arm: 4
# round: 432 best arm: 4
# round: 433 best arm: 4
# round: 434 best arm: 4
# round: 435 best arm: 4
# round: 436 best arm: 4
# round: 437 best arm: 4
# round: 438 best arm: 4
# round: 439 best arm: 4
# round: 440 best arm: 4
# round: 441 best arm: 4
# round: 442 arm: 8
# round: 443 best arm: 8
# round: 444 arm: 3
# round: 445 arm: 1
# round: 446 arm: 6
# round: 447 best arm: 8
# round: 448 best arm: 4
# round: 449 best arm: 4
# round: 450 arm: 0
# round: 451 best arm: 4
# round: 452 best arm: 4
# round: 453 best arm: 4
# round: 454 best arm: 4
# round: 455 arm: 9
# round: 456 best arm: 4
# round: 457 best arm: 4
# round: 458 best arm: 4
# round: 459 best arm: 4
# round: 460 best arm: 4
# round: 461 best arm: 4
# round: 462 arm: 7
# round: 463 best arm: 4
# round: 464 arm: 7
# round: 465 best arm: 4
# round: 466 best arm: 4
# round: 467 arm: 9
# round: 468 best arm: 4
# round: 469 arm: 1
# round: 470 best arm: 4
# round: 471 arm: 4
# round: 472 best arm: 4
# round: 473 best arm: 4
# round: 474 best arm: 4
# round: 475 best arm: 4
# round: 476 best arm: 4
# round: 477 best arm: 4
# round: 478 best arm: 4
# round: 479 arm: 1
# round: 480 arm: 4
# round: 481 best arm: 4
# round: 482 best arm: 4
# round: 483 best arm: 4
# round: 484 best arm: 4
# round: 485 arm: 0
# round: 486 arm: 1
# round: 487 best arm: 4
# round: 488 best arm: 4
# round: 489 best arm: 4
# round: 490 best arm: 4
# round: 491 best arm: 4
# round: 492 best arm: 4
# round: 493 best arm: 4
# round: 494 best arm: 4
# round: 495 best arm: 4
# round: 496 best arm: 4
# round: 497 best arm: 4
# round: 498 best arm: 4
# round: 499 best arm: 8
# round: 500 arm: 2
# round: 501 best arm: 4
# round: 502 best arm: 4
# round: 503 best arm: 4
# round: 504 best arm: 4
# round: 505 best arm: 4
# round: 506 best arm: 4
# round: 507 best arm: 4
# round: 508 best arm: 4
# round: 509 best arm: 4
# round: 510 best arm: 4
# round: 511 arm: 3
# round: 512 best arm: 4
# round: 513 best arm: 4
# round: 514 best arm: 4
# round: 515 arm: 8
# round: 516 best arm: 4
# round: 517 best arm: 4
# round: 518 best arm: 4
# round: 519 best arm: 4
# round: 520 best arm: 4
# round: 521 best arm: 4
# round: 522 arm: 0
# round: 523 best arm: 4
# round: 524 best arm: 4
# round: 525 best arm: 4
# round: 526 best arm: 4
# round: 527 best arm: 4
# round: 528 arm: 1
# round: 529 best arm: 4
# round: 530 best arm: 4
# round: 531 best arm: 4
# round: 532 best arm: 4
# round: 533 arm: 1
# round: 534 arm: 1
# round: 535 best arm: 4
# round: 536 best arm: 4
# round: 537 best arm: 4
# round: 538 best arm: 4
# round: 539 best arm: 4
# round: 540 best arm: 4
# round: 541 best arm: 4
# round: 542 best arm: 4
# round: 543 best arm: 4
# round: 544 best arm: 4
# round: 545 arm: 4
# round: 546 arm: 6
# round: 547 best arm: 4
# round: 548 best arm: 4
# round: 549 best arm: 4
# round: 550 best arm: 4
# round: 551 best arm: 4
# round: 552 arm: 0
# round: 553 best arm: 4
# round: 554 best arm: 4
# round: 555 arm: 9
# round: 556 best arm: 4
# round: 557 best arm: 4
# round: 558 best arm: 4
# round: 559 best arm: 4
# round: 560 best arm: 4
# round: 561 arm: 1
# round: 562 best arm: 4
# round: 563 arm: 6
# round: 564 arm: 6
# round: 565 best arm: 4
# round: 566 best arm: 4
# round: 567 best arm: 4
# round: 568 best arm: 4
# round: 569 arm: 2
# round: 570 arm: 5
# round: 571 best arm: 4
# round: 572 best arm: 4
# round: 573 best arm: 4
# round: 574 best arm: 4
# round: 575 best arm: 4
# round: 576 arm: 7
# round: 577 best arm: 4
# round: 578 best arm: 4
# round: 579 best arm: 4
# round: 580 best arm: 4
# round: 581 best arm: 4
# round: 582 arm: 6
# round: 583 arm: 9
# round: 584 arm: 8
# round: 585 best arm: 4
# round: 586 best arm: 4
# round: 587 arm: 6
# round: 588 best arm: 4
# round: 589 arm: 3
# round: 590 arm: 8
# round: 591 best arm: 4
# round: 592 arm: 8
# round: 593 best arm: 4
# round: 594 best arm: 4
# round: 595 best arm: 4
# round: 596 best arm: 4
# round: 597 arm: 1
# round: 598 arm: 3
# round: 599 best arm: 4
# round: 600 best arm: 4
# round: 601 arm: 8
# round: 602 best arm: 4
# round: 603 best arm: 4
# round: 604 best arm: 4
# round: 605 best arm: 4
# round: 606 best arm: 4
# round: 607 best arm: 4
# round: 608 best arm: 4
# round: 609 best arm: 4
# round: 610 arm: 3
# round: 611 best arm: 4
# round: 612 best arm: 4
# round: 613 arm: 8
# round: 614 arm: 8
# round: 615 best arm: 4
# round: 616 best arm: 4
# round: 617 best arm: 4
# round: 618 best arm: 4
# round: 619 arm: 7
# round: 620 best arm: 4
# round: 621 arm: 5
# round: 622 best arm: 4
# round: 623 arm: 5
# round: 624 best arm: 4
# round: 625 best arm: 4
# round: 626 arm: 0
# round: 627 best arm: 4
# round: 628 best arm: 4
# round: 629 best arm: 4
# round: 630 best arm: 4
# round: 631 best arm: 4
# round: 632 best arm: 4
# round: 633 best arm: 4
# round: 634 arm: 0
# round: 635 best arm: 4
# round: 636 best arm: 4
# round: 637 best arm: 4
# round: 638 best arm: 4
# round: 639 best arm: 4
# round: 640 best arm: 4
# round: 641 arm: 7
# round: 642 arm: 5
# round: 643 best arm: 4
# round: 644 arm: 7
# round: 645 best arm: 4
# round: 646 best arm: 4
# round: 647 best arm: 4
# round: 648 arm: 2
# round: 649 best arm: 4
# round: 650 arm: 9
# round: 651 arm: 2
# round: 652 best arm: 4
# round: 653 best arm: 4
# round: 654 best arm: 4
# round: 655 best arm: 4
# round: 656 arm: 5
# round: 657 best arm: 4
# round: 658 best arm: 4
# round: 659 best arm: 4
# round: 660 arm: 4
# round: 661 arm: 8
# round: 662 arm: 0
# round: 663 best arm: 4
# round: 664 best arm: 4
# round: 665 best arm: 4
# round: 666 best arm: 4
# round: 667 best arm: 4
# round: 668 arm: 6
# round: 669 arm: 4
# round: 670 best arm: 4
# round: 671 best arm: 4
# round: 672 best arm: 4
# round: 673 best arm: 4
# round: 674 arm: 2
# round: 675 best arm: 4
# round: 676 best arm: 4
# round: 677 best arm: 4
# round: 678 best arm: 4
# round: 679 best arm: 4
# round: 680 best arm: 4
# round: 681 best arm: 4
# round: 682 best arm: 4
# round: 683 arm: 5
# round: 684 best arm: 4
# round: 685 best arm: 4
# round: 686 best arm: 4
# round: 687 best arm: 4
# round: 688 best arm: 4
# round: 689 best arm: 4
# round: 690 best arm: 4
# round: 691 best arm: 4
# round: 692 best arm: 4
# round: 693 arm: 9
# round: 694 best arm: 4
# round: 695 arm: 3
# round: 696 arm: 5
# round: 697 best arm: 4
# round: 698 best arm: 4
# round: 699 best arm: 4
# round: 700 best arm: 4
# round: 701 best arm: 4
# round: 702 best arm: 4
# round: 703 best arm: 4
# round: 704 best arm: 4
# round: 705 best arm: 4
# round: 706 arm: 7
# round: 707 best arm: 4
# round: 708 arm: 1
# round: 709 best arm: 4
# round: 710 best arm: 4
# round: 711 best arm: 4
# round: 712 best arm: 4
# round: 713 best arm: 4
# round: 714 best arm: 4
# round: 715 best arm: 4
# round: 716 best arm: 4
# round: 717 best arm: 4
# round: 718 best arm: 4
# round: 719 best arm: 4
# round: 720 best arm: 4
# round: 721 best arm: 4
# round: 722 best arm: 4
# round: 723 best arm: 4
# round: 724 arm: 5
# round: 725 best arm: 4
# round: 726 best arm: 4
# round: 727 best arm: 4
# round: 728 arm: 6
# round: 729 arm: 3
# round: 730 best arm: 4
# round: 731 best arm: 4
# round: 732 best arm: 4
# round: 733 best arm: 4
# round: 734 best arm: 4
# round: 735 best arm: 4
# round: 736 best arm: 4
# round: 737 best arm: 4
# round: 738 arm: 8
# round: 739 arm: 0
# round: 740 best arm: 4
# round: 741 best arm: 4
# round: 742 best arm: 4
# round: 743 best arm: 4
# round: 744 arm: 8
# round: 745 best arm: 4
# round: 746 best arm: 4
# round: 747 best arm: 4
# round: 748 best arm: 4
# round: 749 arm: 6
# round: 750 best arm: 4
# round: 751 best arm: 4
# round: 752 arm: 5
# round: 753 best arm: 4
# round: 754 best arm: 4
# round: 755 best arm: 4
# round: 756 best arm: 4
# round: 757 best arm: 4
# round: 758 best arm: 4
# round: 759 arm: 2
# round: 760 best arm: 4
# round: 761 arm: 3
# round: 762 best arm: 4
# round: 763 best arm: 4
# round: 764 best arm: 4
# round: 765 best arm: 4
# round: 766 arm: 7
# round: 767 best arm: 4
# round: 768 best arm: 4
# round: 769 best arm: 4
# round: 770 best arm: 4
# round: 771 best arm: 4
# round: 772 best arm: 4
# round: 773 best arm: 4
# round: 774 best arm: 4
# round: 775 arm: 1
# round: 776 arm: 9
# round: 777 arm: 6
# round: 778 best arm: 4
# round: 779 best arm: 4
# round: 780 best arm: 4
# round: 781 best arm: 4
# round: 782 best arm: 4
# round: 783 best arm: 4
# round: 784 best arm: 4
# round: 785 best arm: 4
# round: 786 best arm: 4
# round: 787 best arm: 4
# round: 788 best arm: 4
# round: 789 best arm: 4
# round: 790 best arm: 4
# round: 791 best arm: 4
# round: 792 best arm: 4
# round: 793 best arm: 4
# round: 794 best arm: 4
# round: 795 best arm: 4
# round: 796 best arm: 4
# round: 797 best arm: 4
# round: 798 best arm: 4
# round: 799 best arm: 4
# round: 800 best arm: 4
# round: 801 best arm: 4
# round: 802 arm: 6
# round: 803 best arm: 4
# round: 804 best arm: 4
# round: 805 best arm: 4
# round: 806 arm: 1
# round: 807 best arm: 4
# round: 808 best arm: 4
# round: 809 best arm: 4
# round: 810 best arm: 4
# round: 811 arm: 7
# round: 812 best arm: 4
# round: 813 best arm: 4
# round: 814 best arm: 4
# round: 815 arm: 5
# round: 816 best arm: 4
# round: 817 arm: 9
# round: 818 best arm: 4
# round: 819 best arm: 4
# round: 820 best arm: 4
# round: 821 arm: 1
# round: 822 best arm: 4
# round: 823 best arm: 4
# round: 824 best arm: 4
# round: 825 arm: 2
# round: 826 best arm: 4
# round: 827 best arm: 4
# round: 828 best arm: 4
# round: 829 best arm: 4
# round: 830 best arm: 4
# round: 831 best arm: 4
# round: 832 best arm: 4
# round: 833 best arm: 4
# round: 834 arm: 7
# round: 835 best arm: 4
# round: 836 best arm: 4
# round: 837 best arm: 4
# round: 838 best arm: 4
# round: 839 best arm: 4
# round: 840 best arm: 4
# round: 841 best arm: 4
# round: 842 best arm: 4
# round: 843 best arm: 4
# round: 844 best arm: 4
# round: 845 best arm: 4
# round: 846 best arm: 4
# round: 847 best arm: 4
# round: 848 best arm: 4
# round: 849 best arm: 4
# round: 850 best arm: 4
# round: 851 best arm: 4
# round: 852 best arm: 4
# round: 853 best arm: 4
# round: 854 arm: 9
# round: 855 best arm: 4
# round: 856 best arm: 4
# round: 857 best arm: 4
# round: 858 best arm: 4
# round: 859 best arm: 4
# round: 860 best arm: 4
# round: 861 best arm: 4
# round: 862 best arm: 4
# round: 863 best arm: 4
# round: 864 arm: 5
# round: 865 best arm: 4
# round: 866 best arm: 4
# round: 867 best arm: 4
# round: 868 best arm: 4
# round: 869 best arm: 4
# round: 870 best arm: 4
# round: 871 best arm: 4
# round: 872 best arm: 4
# round: 873 best arm: 4
# round: 874 best arm: 4
# round: 875 arm: 0
# round: 876 best arm: 4
# round: 877 best arm: 4
# round: 878 best arm: 4
# round: 879 best arm: 4
# round: 880 arm: 3
# round: 881 best arm: 4
# round: 882 arm: 8
# round: 883 best arm: 4
# round: 884 best arm: 4
# round: 885 best arm: 4
# round: 886 arm: 2
# round: 887 best arm: 4
# round: 888 arm: 0
# round: 889 best arm: 4
# round: 890 best arm: 4
# round: 891 best arm: 4
# round: 892 best arm: 4
# round: 893 best arm: 4
# round: 894 arm: 2
# round: 895 best arm: 4
# round: 896 best arm: 4
# round: 897 best arm: 4
# round: 898 best arm: 4
# round: 899 best arm: 4
# round: 900 best arm: 4
# round: 901 arm: 2
# round: 902 best arm: 4
# round: 903 arm: 2
# round: 904 best arm: 4
# round: 905 best arm: 4
# round: 906 best arm: 4
# round: 907 best arm: 4
# round: 908 best arm: 4
# round: 909 best arm: 4
# round: 910 best arm: 4
# round: 911 best arm: 4
# round: 912 best arm: 4
# round: 913 best arm: 4
# round: 914 best arm: 4
# round: 915 best arm: 4
# round: 916 best arm: 4
# round: 917 best arm: 4
# round: 918 best arm: 4
# round: 919 best arm: 4
# round: 920 best arm: 4
# round: 921 best arm: 4
# round: 922 best arm: 4
# round: 923 arm: 0
# round: 924 arm: 7
# round: 925 best arm: 4
# round: 926 best arm: 4
# round: 927 arm: 3
# round: 928 best arm: 4
# round: 929 best arm: 4
# round: 930 best arm: 4
# round: 931 best arm: 4
# round: 932 best arm: 4
# round: 933 best arm: 4
# round: 934 arm: 4
# round: 935 best arm: 4
# round: 936 arm: 2
# round: 937 best arm: 4
# round: 938 arm: 8
# round: 939 best arm: 4
# round: 940 best arm: 4
# round: 941 best arm: 4
# round: 942 best arm: 4
# round: 943 best arm: 4
# round: 944 best arm: 4
# round: 945 best arm: 4
# round: 946 best arm: 4
# round: 947 best arm: 4
# round: 948 arm: 4
# round: 949 best arm: 4
# round: 950 best arm: 4
# round: 951 best arm: 4
# round: 952 best arm: 4
# round: 953 best arm: 4
# round: 954 best arm: 4
# round: 955 best arm: 4
# round: 956 best arm: 4
# round: 957 arm: 7
# round: 958 arm: 1
# round: 959 best arm: 4
# round: 960 best arm: 4
# round: 961 best arm: 4
# round: 962 arm: 7
# round: 963 best arm: 4
# round: 964 best arm: 4
# round: 965 arm: 5
# round: 966 best arm: 4
# round: 967 best arm: 4
# round: 968 arm: 2
# round: 969 arm: 9
# round: 970 best arm: 4
# round: 971 best arm: 4
# round: 972 arm: 4
# round: 973 best arm: 4
# round: 974 arm: 9
# round: 975 best arm: 4
# round: 976 best arm: 4
# round: 977 best arm: 4
# round: 978 best arm: 4
# round: 979 best arm: 4
# round: 980 arm: 6
# round: 981 best arm: 4
# round: 982 arm: 7
# round: 983 best arm: 4
# round: 984 arm: 3
# round: 985 best arm: 4
# round: 986 arm: 3
# round: 987 best arm: 4
# round: 988 arm: 5
# round: 989 best arm: 4
# round: 990 best arm: 4
# round: 991 best arm: 4
# round: 992 best arm: 4
# round: 993 arm: 4
# round: 994 arm: 6
# round: 995 best arm: 4
# round: 996 best arm: 4
# round: 997 arm: 0
# round: 998 best arm: 4
# round: 999 best arm: 4
# Rounds: 1000  Overall avg reward: 66.1613624200625

# %% [markdown]
# $\large{\textbf{Exercise 4}}$: For the combined explore and exploit strategy, try $m \in \{1,2,4,8,16,32\}$ and scale$\in\{10,20,30,40,50,60,70,80,90\}$ and run the code and tabulate the best arm and average reward obtained at the end of 1000 rounds.
#
# $\large{\textbf{Exercise 5}}$: Try the following expected payouts for the 10 arms and repeat the experiments in Exercise 4.
#
# i) [82.,84.,86.,88.,90.,92.,94.,96.,98.,100.]
# ii) [86., 30., 0., 2., 79., 50., 90., 12., 95., 8.]

# %% [markdown]
# # Multiple Episodes

# %%
#import the required libraries 
import numpy as np
import matplotlib.pyplot as plt 
from timeit import default_timer as timer


n = 10 #number of arms 
expected_payouts = np.asarray([10.,40.,50.,76.,90.,79.,0.,29.,85.,65.])



np.random.seed(100) #for reproducibility

def get_reward(arm):
    reward = np.random.normal(loc=expected_payouts[arm], scale=60)
    if reward<0:
        reward = 0.0
    elif reward > 100.0:
        reward = 100.0
    return reward 

def find_best_arm_combined_explore_exploit_single_episode(avg_rewards_arms):
    best_arm = np.argmax(avg_rewards_arms)
    
    #print('best arm:',(best_arm+1))
    return best_arm

    
def play_multi_armed_bandit_combined_explore_exploit_single_episode(num_rounds):
    k = num_rounds #total rounds 

    avg_rewards_over_rounds = np.zeros(k)

    epsilon = 0.2

    avg_rewards_arms = np.zeros(n)
    freq_arms = np.zeros(n)
    for round_idx in range(k):
        if round_idx == 0: #first round 
            arm = np.random.randint(0, n)
            #print('round:',round_idx,'arm:',arm)
            reward = get_reward(arm)
            avg_rewards_over_rounds[round_idx] = reward
            # we maintain a running average of rewards of each arm            
            avg_rewards_arms[arm] = (avg_rewards_arms[arm]*freq_arms[arm] + reward)/(freq_arms[arm]+1) 
            freq_arms[arm] += 1.
        else: #for other rounds 
            r = np.random.rand()
            best_arm = find_best_arm_combined_explore_exploit_single_episode(avg_rewards_arms)
            if r>epsilon: #use the best arm in the previous history
                #play the best arm so far 
                #print('round:',round_idx,'best arm:',best_arm)
                reward = get_reward(best_arm)
                avg_rewards_over_rounds[round_idx] = (((round_idx)*avg_rewards_over_rounds[round_idx-1])+reward)/(round_idx+1)
                # we maintain a running average of rewards of each arm            
                avg_rewards_arms[best_arm] = (avg_rewards_arms[best_arm]*freq_arms[best_arm] + reward)/(freq_arms[best_arm]+1) 
                freq_arms[best_arm] += 1.
            else: #explore another arm other than the best arm so far
                arm = np.random.randint(0, n)
                #print('round:',round_idx,'arm:',arm)
                while arm==best_arm:
                    arm = np.random.randint(0, n)
                reward = get_reward(arm)
                avg_rewards_over_rounds[round_idx] = (((round_idx)*avg_rewards_over_rounds[round_idx-1])+reward)/(round_idx+1)
                # we maintain a running average of rewards of each arm            
                avg_rewards_arms[arm] = (avg_rewards_arms[arm]*freq_arms[arm] + reward)/(freq_arms[arm]+1) 
                freq_arms[arm] += 1.
            #print(avg_rewards_arms)
                
    

    #print('Rounds:',k,' Overall avg reward:',avg_rewards_over_rounds[-1])

    return avg_rewards_over_rounds
    
def run_multi_armed_bandit_epsiodes_combined_explore_exploit(num_episodes):
    assert num_episodes>0
    long_term_avg_reward = np.zeros(num_episodes)
    num_rounds_in_single_episode = 1000
    for episode in range(num_episodes):
        #print('################### episode: %d #################' %episode)
        avg_rewards_all_rounds_single_episode = play_multi_armed_bandit_combined_explore_exploit_single_episode(num_rounds_in_single_episode)   
        long_term_avg_reward = (episode*long_term_avg_reward + avg_rewards_all_rounds_single_episode)/(episode+1)
        #print('################### end of episode: %d #################' %episode)
    return long_term_avg_reward

if __name__ == '__main__':
    episodes = 1000
    start_time = timer()
    long_term_avg_reward_combined_explore_exploit = run_multi_armed_bandit_epsiodes_combined_explore_exploit(episodes)
    end_time = timer() 
    print('Combined explore and exploit: Time taken for 1000 episodes: ',end_time-start_time, ' seconds!')
    plt.plot(long_term_avg_reward_combined_explore_exploit)    
    plt.xlabel("Round")
    plt.ylabel("Average reward across %d episodes"%episodes)
    plt.title("$\epsilon$ greedy: Average reward behavior over episodes")
    plt.show()
# Out:
# Combined explore and exploit: Time taken for 1000 episodes:  15.076852686000166  seconds!

# %% [markdown]
# $\large{\textbf{Exercise 6}}$: Try $m \in \{1,2,4,8,16,32\}$ and scale$\in\{10,20,30,40,50,60,70,80,90\}$ and run the code for multiple episodes of combined explore and exploit strategy strategy and tabulate the average reward obtained at the end of 1000 episodes.
